# %% [markdown]
# AIPI 510 PROJECT

# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt

# %% [markdown]
# Getting Booking.com Rental Car API:

# %%
import requests
import creds

url = "https://booking-com.p.rapidapi.com/v1/car-rental/search"

querystring = {"drop_off_longitude":"-84.419853","currency":"USD","sort_by":"recommended","drop_off_datetime":"2023-01-03 19:00:00","drop_off_latitude":"33.640411","from_country":"it","pick_up_longitude":"-84.419853","locale":"en-gb","pick_up_datetime":"2023-01-01 19:00:00","pick_up_latitude":"33.640411"}

headers = {
	"X-RapidAPI-Key": f"{creds.api_key}",
	"X-RapidAPI-Host": "booking-com.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
results = response.json()
#df = pd.DataFrame.from_dict(results, orient="index")
#print(results)
# Out:
# {'sort': [{'name': 'Recommended – best first', 'identifier': 'recommended', 'title_tag': 'tr.searchresults.sortBy.recommended'}, {'identifier': 'price_low_to_high', 'title_tag': 'tr.searchresults.sortBy.price.lowHigh', 'name': 'Price - lowest first'}], 'title': 'Car rentals', 'type': 'cars', 'content': {'discountBanner': None}, 'search_results': [{'pricing_info': {'base_currency': 'EUR', 'quote_allowed': 1, 'drive_away_price': 205.07, 'base_price': 200.25, 'fee_breakdown': {'fuel_policy': {'type': 'RETURN_SAME_OR_PREPAY_NO_REFUNDS', 'currency': '', 'amount': 0.0}, 'known_fees': [{'is_always_payable': 0, 'currency': 'USD', 'max_amount': 0.0, 'type': 'DAMAGE_EXCESS', 'amount': 0.0, 'min_amount': 0.0, 'is_tax_included': 1, 'distance_allowed': None}, {'distance_allowed': None, 'amount': 500.0, 'is_tax_included': 1, 'min_amount': 200.0, 'max_amount': 500.0, 'type': 'DEPOSIT', 'is_always_payable': 0, 'currency': 'USD'}, {'is_always_payable': 0, 'currency': 'USD', 'type': 'THEFT_EXCESS', 'max_amount': 0.0, 'min_amount': 0.0, 'is_tax_included': 1, 'amount': 0.0, 'distance_allowed': None}, {'max_amount': None, 'type': 'MILEAGE', 'is_always_payable': 0, 'currency': None, 'distance_allowed': {'value': None, 'per_duration': None, 'is_km': 1, 'is_unlimited': 1}, 'amount': None, 'min_amount': None, 'is_tax_included': None}]}, 'pay_when': 'PAY_NOW', 'drive_away_price_is_approx': True, 'base_deposit': 200.25, 'currency': 'USD', 'price': 205.07, 'drive_away_price_before': None, 'discount': 0.0, 'deposit': 205.07}, 'supplier_info': {'pickup_instructions': 'Please take the "SkyTrain" to the "Rental Car Center".', 'latitude': '33.640874', 'location_type': 'Car Rental Centre', 'address': '2300, Rental Car Center Parkway, Atlanta, GA, USA, 30337', 'dropoff_instructions': 'Please take the "SkyTrain" to the "Rental Car Center".', 'name': 'Thrifty', 'logo_url': 'https://cdn.rcstatic.com/sp/images/suppliers/227_logo_200.png', 'may_require_credit_card_guarantee': False, 'longitude': '-84.445126'}, 'fee_info': {'tax': 0, 'type': '', 'currency': '', 'fee': 0.0}, 'route_info': {'dropoff': {'city': '', 'country_code': 'US', 'country': '', 'longitude': '-84.445126', 'location_id': '3652831', 'latitude': '33.640874', 'icon': '', 'location_type': 'CAR_RENTAL_CENTRE', 'address': '2300, Rental Car Center Parkway, Atlanta, GA, USA, 30337', 'name': 'Atlanta Airport'}, 'pickup': {'longitude': '-84.445126', 'country_code': 'US', 'country': '', 'city': '', 'name': 'Atlanta Airport', 'address': '2300, Rental Car Center Parkway, Atlanta, GA, USA, 30337', 'icon': '', 'location_type': 'CAR_RENTAL_CENTRE', 'location_id': '3652831', 'latitude': '33.640874'}}, 'accessibility': {'transmission': 'Automatic gearbox', 'fuel_policy': 'Fuel policy is: Like for like', 'pick_up_location': 'Pick-up information: Car Rental Centre', 'supplier_rating': 'At this location, our customers have rated Thrifty, 6.5 out of 10'}, 'applied_discount_types': [], 'rating_info': {'cleanliness': 6.6, 'pickup_time': 5.0, 'value_for_money': 6.3, 'efficiency': 5.5, 'dropoff_time': 9.3, 'average': 6.5, 'condition': 6.4, 'location': 7.3, 'no_of_ratings': 596, 'average_text': 'Good'}, 'freebies': ['Amendments'], 'vehicle_info': {'fuel_type': 'N/A', 'fuel_policy_description': '', 'doors': '4', 'badges': {}, 'free_cancellation': 1, 'aircon': 1, 'unlimited_mileage': 1, 'group': 'Compact', 'label': 'Compact car with:', 'insurance_package': '', 'special_offer_text': None, 'v_name': 'Ford Focus  ', 'image_thumbnail_url': 'https://cdn.rcstatic.com/images/car_images/web/ford/focus_lrg.png', 'image_url': 'https://cdn.rcstatic.com/images/car_images/web/ford/focus_lrg.png', 'transmission': 'Automatic', 'fuel_policy': 'Like for like', 'airbags': 1, 'mileage': 'Unlimited km', 'cma_compliant': -1, 'suitcases': {'big': '0', 'small': '3'}, 'seats': '5', 'v_id': '631938718'}, 'content': {'badges': [{'type': 'CONSTRUCTIVE', 'variation': 'DEFAULT', 'text': 'Free cancellation'}]}}, {'fee_info': {'tax': 0, 'type': '', 'fee': 0 ...

# %%
df = pd.DataFrame.from_dict(results['search_results'])
df
# Out:
#                                            rating_info  \
# 0    {'pickup_time': 5.0, 'average_text': 'Good', '...
# 1    {'location': 7.7, 'cleanliness': 7.6, 'dropoff...
# 2    {'location': 7.7, 'cleanliness': 7.6, 'efficie...
# 3    {'efficiency': 5.5, 'no_of_ratings': 596, 'dro...
# 4    {'average_text': 'Good', 'pickup_time': 5.0, '...
# ..                                                 ...
# 334  {'cleanliness': 9.4, 'location': 9.0, 'conditi...
# 335  {'location': 9.1, 'cleanliness': 9.1, 'value_f...
# 336  {'location': 9.1, 'cleanliness': 9.3, 'value_f...
# 337  {'average_text': 'Excellent', 'pickup_time': 7...
# 338  {'no_of_ratings': 47, 'efficiency': 8.9, 'valu...
#
#                                          accessibility  \
# 0    {'fuel_policy': 'Fuel policy is: Like for like...
# 1    {'fuel_policy': 'Fuel policy is: Like for like...
# 2    {'pick_up_location': 'Pick-up information: Car...
# 3    {'pick_up_location': 'Pick-up information: Car...
# 4    {'supplier_rating': 'At this location, our cus...
# ..                                                 ...
# 334  {'pick_up_location': 'Pick-up information: Car...
# 335  {'pick_up_location': 'Pick-up information: {lo...
# 336  {'fuel_policy': 'Fuel policy is: Free Tank', '...
# 337  {'supplier_rating': 'At this location, our cus...
# 338  {'pick_up_location': 'Pick-up information: Car...
#
#                                             route_info  \
# 0    {'pickup': {'country_code': 'US', 'address': '...
# 1    {'dropoff': {'latitude': '33.640874', 'address...
# 2    {'pickup': {'latitude': '33.640874', 'country_...
# 3    {'pickup': {'longitude': '-84.445126', 'city':...
# 4    {'pickup': {'country_code': 'US', 'address': '...
# ..                                                 ...
# 334  {'pickup': {'longitude': '-84.4636', 'location...
# 335  {'pickup': {'icon': '', 'city': '', 'location_...
# 336  {'dropoff': {'latitude': '33.6397', 'country_c...
# 337  {'dropoff': {'address': '2200, RENTAL CAR CENT...
# 338  {'pickup': {'address': '2200, RENTAL CAR CNTR ...
#
#                                           pricing_info  \
# 0    {'pay_when': 'PAY_NOW', 'base_deposit': 45.0, ...
# 1    {'drive_away_price_before': None, 'drive_away_...
# 2    {'fee_breakdown': {'known_fees': [{'type': 'TH...
# 3    {'discount': 0.0, 'price': 242.59, 'drive_away...
# 4    {'base_currency': 'EUR', 'fee_breakdown': {'kn...
# ..                                                 ...
# 334  {'drive_away_price_before': None, 'deposit': 5...
# 335  {'drive_away_price_before': None, 'deposit': 5...
# 336  {'base_currency': 'EUR', 'fee_breakdown': {'kn...
# 337  {'currency': 'USD', 'drive_away_price_is_appro...
# 338  {'drive_away_price_before': None, 'drive_away_...
#
#                                          supplier_info      freebies  \
# 0    {'longitude': '-84.445126', 'pickup_instructio...  [Amendments]
# 1    {'logo_url': 'https://cdn.rcstatic.com/sp/imag...  [Amendments]
# 2    {'latitude': '33.640874', 'may_require_credit_...  [Amendments]
# 3    {'may_require_credit_card_guarantee': False, '...  [Amendments]
# 4    {'longitude': '-84.445126', 'pickup_instructio...  [Amendments]
# ..                                                 ...           ...
# 334  {'latitude': '33.6397', 'may_require_credit_ca...  [Amendments]
# 335  {'location_type': None, 'dropoff_instructions'...  [Amendments]
# 336  {'pickup_instructions': 'Take the SkyTrain to ...  [Amendments]
# 337  {'latitude': '33.643417', 'may_require_credit_...  [Amendments]
# 338  {'longitude': '-84.4636', 'pickup_instructions...  [Amendments]
#
#     applied_discount_types                                       vehicle_info  \
# 0                       []  {'badges': {}, 'seats': '5', 'airbags': 1, 'cm...
# 1                       []  {'badges': {}, 'seats': '5', 'airbags': 1, 'cm...
# 2                       []  {'v_name': 'Buick Encore', 'v_id': '697010086'...
# 3                       []  {'fuel_policy_description': '', 'v_name': 'Toy...
# 4                       []  {'fuel_type': 'N/A', 'label': 'Compact car wit...
# ..                     ...                                                ...
# 334                     []  {'v_name': 'Mitsubishi Mirage  ', 'mileage': '...
# 335                     []  {'label': 'Economy car with:', 'fuel_type': 'N...
# 336                     []  {'seats': '5', 'badges': {}, 'cma_compliant': ...
# 337                     []  {'suitcases': {'small': '2', 'big': '0'}, 'ima...
# 338                     []  {'aircon': 1, 'fuel_type': 'N/A', 'label': 'Ec...
#
#                                               fee_info  \
# 0    {'fee': 0.0, 'tax': 0, 'currency': '', 'type':...
# 1    {'currency': '', 'type': '', 'fee': 0.0, 'tax'...
# 2    {'fee': 0.0, 'tax': 0, 'currency': '', 'type':...
# 3    {'tax': 0, 'fee': 0.0, 'type': '', 'currency':...
# 4    {'fee': 0.0, 'tax': 0, 'currency': '', 'type':...
# ..                                                 ...
# 334  {'tax': 0, 'fee': 0.0, 'type': '', 'currency':...
# 335  {'fee': 0.0, 'tax': 0, 'currency': '', 'type':...
# 336  {'tax': 0, 'fee': 0.0, 'type': '', 'currency':...
# 337  {'tax': 0, 'fee': 0.0, 'type': '', 'currency':...
# 338  {'tax': 0, 'fee': 0.0, 'type': '', 'currency':...
#
#                                                content
# 0    {'badges': [{'type': 'CONSTRUCTIVE', 'text': '...
# 1    {'badges': [{'variation': 'DEFAULT', 'text': '...
# 2    {'badges': [{'type': 'CONSTRUCTIVE', 'text': '...
# 3    {'badges': [{'type': 'CONSTRUCTIVE', 'text': '...
# 4    {'badges': [{'text': 'Free cancellation', 'var...
# ..                                                 ...
# 334  {'badges': [{'type': 'CONSTRUCTIVE', 'text': '...
# 335  {'badges': [{'type': 'CONSTRUCTIVE', 'variatio...
# 336  {'badges': [{'text': 'Free cancellation', 'var...
# 337  {'badges': [{'variation': 'DEFAULT', 'text': '...
# 338  {'badges': [{'variation': 'DEFAULT', 'text': '...
#
# [339 rows x 10 columns]

# %%
#this will expand all the json into separate columns but so many columns as seen below!
df2 = pd.json_normalize(results, record_path =['search_results'])
df2
# Out:
#          freebies applied_discount_types  rating_info.location  \
# 0    [Amendments]                     []                   9.1
# 1    [Amendments]                     []                   7.7
# 2    [Amendments]                     []                   7.6
# 3    [Amendments]                     []                   9.1
# 4    [Amendments]                     []                   9.1
# ..            ...                    ...                   ...
# 334  [Amendments]                     []                   9.1
# 335  [Amendments]                     []                   9.1
# 336  [Amendments]                     []                   9.0
# 337  [Amendments]                     []                   7.7
# 338  [Amendments]                     []                   7.7
#
#      rating_info.condition  rating_info.pickup_time rating_info.average_text  \
# 0                      9.2                      7.7                Excellent
# 1                      7.7                      6.3                Very good
# 2                      6.5                      5.2                     Good
# 3                      9.2                      7.7                Excellent
# 4                      8.5                      7.8                Excellent
# ..                     ...                      ...                      ...
# 334                    9.2                      7.7                Excellent
# 335                    9.2                      7.7                Excellent
# 336                    9.0                      8.6                   Superb
# 337                    7.7                      6.3                Very good
# 338                    7.7                      6.3                Very good
#
#      rating_info.no_of_ratings  rating_info.dropoff_time  \
# 0                         1092                       9.7
# 1                          446                       9.1
# 2                          594                       9.4
# 3                         1092                       9.7
# 4                           15                       8.9
# ..                         ...                       ...
# 334                       1092                       9.7
# 335                       1092                       9.7
# 336                         47                       9.7
# 337                        446                       9.1
# 338                        446                       9.1
#
#      rating_info.efficiency  rating_info.cleanliness  ...  \
# 0                       8.8                      9.3  ...
# 1                       6.6                      7.6  ...
# 2                       5.7                      6.8  ...
# 3                       8.8                      9.3  ...
# 4                       8.0                      9.1  ...
# ..                      ...                      ...  ...
# 334                     8.8                      9.3  ...
# 335                     8.8                      9.3  ...
# 336                     8.9                      9.4  ...
# 337                     6.6                      7.6  ...
# 338                     6.6                      7.6  ...
#
#      vehicle_info.transmission  vehicle_info.fuel_policy_description  \
# 0                    Automatic
# 1                    Automatic
# 2                    Automatic
# 3                    Automatic
# 4                    Automatic
# ..                         ...                                   ...
# 334                  Automatic
# 335                  Automatic
# 336                  Automatic
# 337                  Automatic
# 338                  Automatic
#
#                        vehicle_info.special_offer_text  \
# 0                             1 free additional driver
# 1                                                 None
# 2                                                 None
# 3                             1 free additional driver
# 4                                                 None
# ..                                                 ...
# 334                                               None
# 335  Young Driver Premium Package: Price includes y...
# 336  Premium Sat-Nav package – All additional drive...
# 337  Free tank of fuel, child seat rental and up to...
# 338                   Free tank of fuel and child seat
#
#     vehicle_info.suitcases.big vehicle_info.suitcases.small  \
# 0                            0                            4
# 1                            0                            4
# 2                            0                            5
# 3                            0                            4
# 4                            0                            4
# ..                         ...                          ...
# 334                          0                            2
# 335                          0                            2
# 336                          0                            2
# 337                          0                            5
# 338                          0                            5
#
#     vehicle_info.group vehicle_info.fuel_type      vehicle_info.label  \
# 0         Intermediate                    N/A  Intermediate car with:
# 1              Premium                    N/A       Premium car with:
# 2              Premium                    N/A       Premium car with:
# 3         Intermediate                    N/A  Intermediate car with:
# 4         Intermediate                    N/A  Intermediate car with:
# ..                 ...                    ...                     ...
# 334           Standard                    N/A      Standard car with:
# 335            Economy                    N/A       Economy car with:
# 336            Economy                    N/A       Economy car with:
# 337            Premium                    N/A       Premium car with:
# 338            Premium                    N/A       Premium car with:
#
#     vehicle_info.aircon  vehicle_info.cma_compliant
# 0                     1                          -1
# 1                     1                          -1
# 2                     1                          -1
# 3                     1                          -1
# 4                     1                          -1
# ..                  ...                         ...
# 334                   1                          -1
# 335                   1                          -1
# 336                   1                          -1
# 337                   1                          -1
# 338                   1                          -1
#
# [339 rows x 88 columns]

# %%
#list of the columns to choose to include...
df2.columns
# Out:
# Index(['freebies', 'applied_discount_types', 'rating_info.location',
#        'rating_info.condition', 'rating_info.pickup_time',
#        'rating_info.average_text', 'rating_info.no_of_ratings',
#        'rating_info.dropoff_time', 'rating_info.efficiency',
#        'rating_info.cleanliness', 'rating_info.average',
#        'rating_info.value_for_money', 'content.badges',
#        'accessibility.transmission', 'accessibility.fuel_policy',
#        'accessibility.pick_up_location', 'accessibility.supplier_rating',
#        'fee_info.currency', 'fee_info.type', 'fee_info.fee', 'fee_info.tax',
#        'pricing_info.fee_breakdown.known_fees',
#        'pricing_info.fee_breakdown.fuel_policy.type',
#        'pricing_info.fee_breakdown.fuel_policy.currency',
#        'pricing_info.fee_breakdown.fuel_policy.amount', 'pricing_info.price',
#        'pricing_info.base_deposit', 'pricing_info.drive_away_price_is_approx',
#        'pricing_info.drive_away_price_before', 'pricing_info.base_price',
#        'pricing_info.pay_when', 'pricing_info.drive_away_price',
#        'pricing_info.deposit', 'pricing_info.currency',
#        'pricing_info.quote_allowed', 'pricing_info.discount',
#        'pricing_info.base_currency', 'supplier_info.pickup_instructions',
#        'supplier_info.longitude', 'supplier_info.location_type',
#        'supplier_info.address',
#        'supplier_info.may_require_credit_card_guarantee',
#        'supplier_info.dropoff_instructions', 'supplier_info.logo_url',
#        'supplier_info.latitude', 'supplier_info.name',
#        'route_info.dropoff.latitude', 'route_info.dropoff.country_code',
#        'route_info.dropoff.name', 'route_info.dropoff.address',
#        'route_info.dropoff.location_id', 'route_info.dropoff.city',
#        'route_info.dropoff.longitude', 'route_info.dropoff.location_type',
#        'route_info.dropoff.country', 'route_info.dropoff.icon',
#        'route_info.pickup.location_id', 'route_info.pickup.city',
#        'route_info.pickup.address', 'route_info.pickup.latitude',
#        'route_info.pickup.name', 'route_info.pickup.country_code',
#        'route_info.pickup.icon', 'route_info.pickup.country',
#        'route_info.pickup.location_type', 'route_info.pickup.longitude',
#        'vehicle_info.unlimited_mileage', 'vehicle_info.insurance_package',
#        'vehicle_info.doors', 'vehicle_info.image_url', 'vehicle_info.v_id',
#        'vehicle_info.v_name', 'vehicle_info.mileage',
#        'vehicle_info.free_cancellation', 'vehicle_info.airbags',
#        'vehicle_info.seats', 'vehicle_info.image_thumbnail_url',
#        'vehicle_info.fuel_policy', 'vehicle_info.transmission',
#        'vehicle_info.fuel_policy_description',
#        'vehicle_info.special_offer_text', 'vehicle_info.suitcases.big',
#        'vehicle_info.suitcases.small', 'vehicle_info.group',
#        'vehicle_info.fuel_type', 'vehicle_info.label', 'vehicle_info.aircon',
#        'vehicle_info.cma_compliant'],
#       dtype='object')

# %%
df2['vehicle_info.group'].value_counts()
# Out:
# Standard        79
# Full-size       65
# Intermediate    63
# Premium         41
# Compact         31
# Luxury          27
# Economy         24
# Mini             6
# Special          3
# Name: vehicle_info.group, dtype: int64

# %%
def clean_api_df(data_df):
  df_cleaned = data_df.copy()
  
  #filter to the columns we want to keep
  columns_to_keep = ['vehicle_info.v_id', 'vehicle_info.v_name', 'vehicle_info.group', 'vehicle_info.transmission', 'route_info.dropoff.city', 'pricing_info.base_price', 'route_info.pickup.city']
  #filter to the types of vehicles in vehicle.group
  vehicle_groups_to_keep = ['Luxury']
  df_cleaned=df_cleaned[columns_to_keep]
  df_cleaned=df_cleaned[df_cleaned['vehicle_info.group'].isin(vehicle_groups_to_keep)]
  df_cleaned.rename(columns={'vehicle_info.v_id':'Vehicle_id', 'vehicle_info.v_name': 'Vehicle_Name', 'vehicle_info.group': 'Category', 'pricing_info.base_price': 'Base_Price','vehicle_info.transmission': 'Transmission', 'route_info.dropoff.city': 'Dropoff_City', 'route_info.pickup.city': 'Pickup_City'}, inplace=True)
  df_cleaned.sort_values(by='Base_Price', ascending=False, inplace=True)
  return df_cleaned

# %%
df_cleaned = clean_api_df(df2)
df_cleaned
# Out:
#     Vehicle_id         Vehicle Name Category Transmission Dropoff City  \
# 214  644881573       Cadillac XTS     Luxury    Automatic
# 110  673928006    Mercedes-Benz GLC   Luxury    Automatic
# 207  636479888       Cadillac XTS     Luxury    Automatic
# 202  646119413         Cadillac XTS   Luxury    Automatic
# 142  674291426  Lincoln Continental   Luxury    Automatic
# 181  644901168       Cadillac XTS     Luxury    Automatic
# 136  723428946         BMW 5 Series   Luxury    Automatic
# 180  636492688       Cadillac XTS     Luxury    Automatic
# 108  631553768  Lincoln Continental   Luxury    Automatic
# 121  644861493       Cadillac XTS     Luxury    Automatic
# 125  646151293         Cadillac XTS   Luxury    Automatic
# 146  658137488         Chrysler 300   Luxury    Automatic
# 148  658190013         Chrysler 300   Luxury    Automatic
# 119  636472613       Cadillac XTS     Luxury    Automatic
# 36   644841863       Cadillac XTS     Luxury    Automatic
# 77   646141193         Cadillac XTS   Luxury    Automatic
# 40   735898091       Cadillac XTS     Luxury    Automatic
# 80   659534556         Chrysler 300   Luxury    Automatic
# 70   643095306     Buick LaCrosse     Luxury    Automatic
# 65   642896921       Chrysler 300     Luxury    Automatic
# 111  658163273         Chrysler 300   Luxury    Automatic
# 29   636464758       Cadillac XTS     Luxury    Automatic
# 12   735895261       Cadillac XTS     Luxury    Automatic
# 23   638446461       Chrysler 300     Luxury    Automatic
# 26   638489136       Chrysler 300     Luxury    Automatic
# 10   631938698     Buick LaCrosse     Luxury    Automatic
# 8    585207183       Chrysler 300     Luxury    Automatic
#
#      Base Price Pickup City
# 214      379.75
# 110      367.62
# 207      365.86
# 202      354.34
# 142      352.44
# 181      344.96
# 136      338.18
# 180      331.29
# 108      328.93
# 121      321.76
# 125      319.76
# 146      319.03
# 148      316.49
# 119      308.24
# 36       298.56
# 77       296.71
# 40       296.71
# 80       296.19
# 70       293.65
# 65       293.65
# 111      291.12
# 29       285.20
# 12       273.66
# 23       273.35
# 26       273.35
# 10       268.28
# 8        268.28

# %%
#going to look at a different date; we still don't have inventory or number of rentals for different dates
querystring2 = {"drop_off_longitude":"-84.419853","currency":"USD","sort_by":"recommended","drop_off_datetime":"2022-11-20 19:00:00","drop_off_latitude":"33.640411","from_country":"it","pick_up_longitude":"-84.419853","locale":"en-gb","pick_up_datetime":"2022-11-18 19:00:00","pick_up_latitude":"33.640411"}
response2 = requests.request("GET", url, headers=headers, params=querystring2)
results2 = response2.json()
df_attempt2 = pd.json_normalize(results2, record_path =['search_results'])
df_cleaned_attempt2 = clean_api_df(df_attempt2)
df_cleaned_attempt2
# Out:
#     Vehicle_id       Vehicle Name Category Transmission Dropoff City  \
# 19   644841863     Cadillac XTS     Luxury    Automatic
# 20   735895261     Cadillac XTS     Luxury    Automatic
# 34   735898091     Cadillac XTS     Luxury    Automatic
# 36   636464758     Cadillac XTS     Luxury    Automatic
# 89   646141193       Cadillac XTS   Luxury    Automatic
# 113  644861493     Cadillac XTS     Luxury    Automatic
# 122  644901168     Cadillac XTS     Luxury    Automatic
# 142  636492688     Cadillac XTS     Luxury    Automatic
# 143  646151293       Cadillac XTS   Luxury    Automatic
# 146  636472613     Cadillac XTS     Luxury    Automatic
# 149  646119413       Cadillac XTS   Luxury    Automatic
# 181  644881573     Cadillac XTS     Luxury    Automatic
# 190  636479888     Cadillac XTS     Luxury    Automatic
# 258  673928006  Mercedes-Benz GLC   Luxury    Automatic
# 285  723428946       BMW 5 Series   Luxury    Automatic
#
#      pricing_info.base_price Pickup City
# 19                    164.33
# 20                    140.29
# 34                    163.31
# 36                    151.80
# 89                    163.31
# 113                   187.56
# 122                   210.71
# 142                   197.91
# 143                   186.39
# 146                   174.85
# 149                   220.96
# 181                   245.52
# 190                   232.48
# 258                   350.80
# 285                   322.76
